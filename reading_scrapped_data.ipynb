# %%
import pandas as pd

# %%
# Read CSV
df = pd.read_csv("data/myhome_listings_en.csv", )

# %%
df.columns
# Out:
# Index(['ID', 'Title', 'Price', 'Price per m²', 'Currency', 'Location',
#        'District', 'Floors', 'Rooms', 'Bedroom(s)', 'Square meter',
#        'Post Date', 'URL'],
#       dtype='object')

# %%
df
# Out:
#            ID                                Title      Price  Price per m²  \
# 0    21994936   იყიდება 2 ოთახიანი ბინა ვარკეთილში    175,110        3184.0
# 1    21623262       იყიდება 5 ოთახიანი ბინა ვაკეში  1,050,660        6486.0
# 2    21876517  იყიდება 2 ოთახიანი ბინა საბურთალოზე    228,990        4771.0
# 3    22161217     იყიდება 3 ოთახიანი ბინა თბილისში    257,277        3066.0
# 4    22088448  იყიდება 2 ოთახიანი ბინა საბურთალოზე    363,690        6271.0
# ..        ...                                  ...        ...           ...
# 195  22131582     იყიდება 5 ოთახიანი ბინა თბილისში    494,753        3665.0
# 196  22083555     იყიდება 2 ოთახიანი ბინა თბილისში    363,690        5595.0
# 197  22087905  იყიდება 3 ოთახიანი ბინა დიდ დიღომში    261,318        4115.0
# 198  21716102     იყიდება 3 ოთახიანი ბინა თბილისში    218,888        3368.0
# 199  16430756  იყიდება 3 ოთახიანი ბინა სან. ზონაში    282,870        4041.0
#
# ...

# %%
ids = [22102551, 22172851, 21689230, 20625319]

# %%
# Save DataFrame to Excel
# df.to_excel("myhome_იყიდება_ბინა_თბილისში.xlsx", engine='openpyxl')  # index=True keeps the ID index
